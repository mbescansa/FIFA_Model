# %% [markdown]
# # Study case | FIFA

# %% [markdown]
# ## 01 - Problem (case study)

# %% [markdown]
# ### Data Description

# %% [markdown]
# Data provided in a csv table with the following features:
#
# * Number of rows: 13700
# * Number of columns: 102 <br>
# <br>
# * Number of numerical variables: 54
# * Numbre of categorical/non-numerical variables: 48

# %% [markdown]
# ## 01 - Goal

# %% [markdown]
# The objective of this data is to understand the scoring of FIFA players. We will use predictive analytics to build a model that can predict their overall score based on multiple variables.

# %% [markdown]
# ## 02 - Getting Data and Preparing Notebook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
import scipy.stats as stats
from sklearn import linear_model
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %%
# To make run all you ask in one cell, not only the last required
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# Open file and show shape 
data=pd.read_csv('C:/Student/IRONHACK/Week2/D1/Case_study/fifa21_trainning.csv')
data.shape

numerical = data.select_dtypes(np.number)
categorical = data.select_dtypes(np.object)
numerical.shape
categorical.shape
data.head(2)
# Out:
# (13700, 102)
# (13700, 54)
# (13700, 48)
#    Unnamed: 0      ID           Name  Age  Nationality  \
# 0        1954  184383      A. Pasche   26  Switzerland
# 1        2225  188044  Alan Carvalho   30     China PR
#
#                       Club  BP  Position  \
# 0        FC Lausanne-Sport  CM    CM CDM
# 1  Beijing Sinobo Guoan FC  ST  ST LW LM
#
#                                 Team & Contract Height  ...   CDM   RDM   RWB  \
# 0                 FC Lausanne-Sport 2015 ~ 2020   5'9"  ...  59+1  59+1  59+1
# 1  Beijing Sinobo Guoan FC Dec 31, 2020 On Loan   6'0"  ...  53+2  53+2  57+2
#
#      LB   LCB    CB   RCB    RB    GK  OVA
# 0  58+1  54+1  54+1  54+1  58+1  15+1   64
# 1  53+2  48+2  48+2  48+2  53+2  18+2   77
#
# [2 rows x 102 columns]

# %% [markdown]
# ## 03 - Cleaning/Wrangling/EDA

# %%
numerical.columns
categorical.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'Age', 'Growth', 'Attacking', 'Crossing',
#        'Finishing', 'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill',
#        'Dribbling', 'Curve', 'FK Accuracy', 'Long Passing', 'Ball Control',
#        'Movement', 'Acceleration', 'Sprint Speed', 'Agility', 'Reactions',
#        'Balance', 'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength',
#        'Long Shots', 'Mentality', 'Aggression', 'Interceptions', 'Positioning',
#        'Vision', 'Penalties', 'Composure', 'Defending', 'Marking',
#        'Standing Tackle', 'Sliding Tackle', 'Goalkeeping', 'GK Diving',
#        'GK Handling', 'GK Kicking', 'GK Positioning', 'GK Reflexes',
#        'Total Stats', 'Base Stats', 'PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY',
#        'OVA'],
#       dtype='object')
# Index(['Name', 'Nationality', 'Club', 'BP', 'Position', 'Team & Contract',
#        'Height', 'Weight', 'foot', 'Joined', 'Loan Date End', 'Value', 'Wage',
#        'Release Clause', 'Contract', 'W/F', 'SM', 'A/W', 'D/W', 'IR', 'Hits',
#        'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM',
#        'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'GK'],
#       dtype='object')

# %%
# Describe
numerical.describe()
categorical.describe()
# Out:
#          Unnamed: 0             ID           Age        Growth     Attacking  \
# count  13700.000000   13700.000000  13700.000000  13700.000000  13700.000000
# mean    8561.641971  219378.929708     25.286058      5.509927    258.313431
# std     4954.144383   37445.343736      4.944498      5.797176     72.412379
# min        1.000000      16.000000     16.000000     -1.000000     33.000000
# 25%     4269.750000  203979.750000     21.000000      0.000000    231.000000
# 50%     8555.500000  228927.000000     25.000000      4.000000    271.000000
# 75%    12887.250000  244043.500000     29.000000      9.000000    306.000000
# max    17122.000000  259091.000000     47.000000     26.000000    437.000000
#
#            Crossing     Finishing  Heading Accuracy  Short Passing  \
# count  13700.000000  13700.000000      13700.000000   13700.000000
# mean      51.585766     47.996934         53.460292      60.427956
# std       17.899930     19.411530         17.010578      13.975634
# min        6.000000      3.000000          5.000000       8.000000
# 25%       41.000000     33.000000         45.000000      56.000000
# 50%       56.000000     52.000000         56.000000      63.000000
# 75%       65.000000     64.000000         65.000000      69.000000
# max       94.000000     95.000000         93.000000      94.000000
#
#             Volleys  ...   GK Reflexes   Total Stats    Base Stats  \
# count  13656.000000  ...  13700.000000  13700.000000  13700.000000
# mean      44.986965  ...     15.830292   1630.103942    361.317007
# std       17.760924  ...     17.276491    260.986045     40.258414
# min        4.000000  ...      1.000000    731.000000    228.000000
# 25%       32.000000  ...      8.000000   1491.000000    333.000000
# 50%       47.000000  ...     11.000000   1659.000000    362.000000
# 75%       59.000000  ...     14.000000   1811.250000    389.000000
# max       90.000000  ...     90.000000   2304.000000    498.000000
#
#                 PAC           SHO           PAS           DRI           DEF  \
# count  13700.000000  13700.000000  13700.000000  13700.000000  13700.000000
# mean      68.108832     55.056423     58.931679     64.236277     50.123577
# std       11.183342     13.839958     10.159851      9.816203     16.815110
# min       26.000000     17.000000     25.000000     28.000000     12.000000
# 25%       62.000000     46.000000     52.000000     59.000000     35.000000
# 50%       69.000000     58.000000     60.000000     65.000000     53.000000
# 75%       75.000000     65.000000     66.000000     71.000000     64.000000
# max       96.000000     93.000000     93.000000     95.000000     90.000000
#
#                 PHY           OVA
# count  13700.000000  13700.000000
# mean      64.860219     66.945912
# std        9.736964      6.860189
# min       27.000000     38.000000
# 25%       59.000000     62.000000
# 50%       66.000000     67.000000
# 75%       72.000000     72.000000
# max       93.000000     93.000000
#
# [8 rows x 54 columns]
#             Name Nationality     Club     BP Position Team & Contract Height  \
# count      13700       13700    13679  13700    13357           13700  13700
# unique     13064         160      897     15      583            8524     21
# top     J. Rojas     England  Everton     CB       CB      India Free   6'0"
# freq           8        1342       38   2553     1595              30   2053
#
#         Weight   foot       Joined  ...    LDM    CDM    RDM    RWB     LB  \
# count    13700  13700        13656  ...  13700  13700  13700  13700  13700
# unique      55      2         1803  ...    301    301    301    271    265
# top     154lbs  Right  Jul 1, 2019  ...   59+2   59+2   59+2   59+2   62+2
# freq      1073  10322          940  ...    410    410    410    514    454
#
#           LCB     CB    RCB     RB     GK
# count   13700  13700  13700  13700  13700
# unique    321    321    321    265    158
# top      61+2   61+2   61+2   62+2   16+2
# freq      360    360    360    454   2510
#
# [4 rows x 48 columns]

# %%
numerical.head()
# Out:
#    Unnamed: 0      ID  Age  Growth  Attacking  Crossing  Finishing  \
# 0        1954  184383   26       1        258        54         47
# 1        2225  188044   30       0        365        66         79
# 2        1959  184431   33       0        336        73         76
# 3        9815  233796   22      13        242        44         42
# 4       10074  234799   23       8        249        49         37
#
#    Heading Accuracy  Short Passing  Volleys  ...  GK Reflexes  Total Stats  \
# 0                43             70     44.0  ...            6         1682
# 1                76             68     76.0  ...           16         1961
# 2                34             78     75.0  ...            3         1925
# 3                58             62     36.0  ...           12         1527
# 4                61             68     34.0  ...           15         1664
#
#    Base Stats  PAC  SHO  PAS  DRI  DEF  PHY  OVA
# 0         357   69   51   63   63   51   60   64
# 1         412   83   75   68   82   33   71   77
# 2         404   80   77   78   86   27   56   80
# 3         329   57   44   54   57   57   60   59
# 4         360   66   44   60   64   60   66   65
#
# [5 rows x 54 columns]

# %% [markdown]
# #### Data cleaning and formating

# %%
# Clean categorical 
data.drop(['Unnamed: 0','LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM',
       'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
       'LCB', 'CB', 'RCB', 'RB', 'GK','Position', 'Team & Contract', 'Joined', 'Loan Date End','Release Clause', 
           'Contract','Attacking', 'Skill','Movement', 'Power' ,'Mentality','Defending', 'Goalkeeping',
          'Total Stats','Base Stats'], axis=1, inplace=True)
data.shape
# Out:
# (13700, 59)

# %%
numerical = data.select_dtypes(np.number)
categorical = data.select_dtypes(np.object)
numerical.shape
categorical.head(2)
data.head(2)
# Out:
# (13700, 44)
#             Name  Nationality                     Club  BP Height  Weight  \
# 0      A. Pasche  Switzerland        FC Lausanne-Sport  CM   5'9"  161lbs
# 1  Alan Carvalho     China PR  Beijing Sinobo Guoan FC  ST   6'0"  159lbs
#
#     foot  Value  Wage  W/F  SM   A/W     D/W   IR Hits
# 0  Right  €525K   €4K  4 ★  2★  High  Medium  1 ★    3
# 1  Right  €8.5M  €23K  3 ★  4★  High     Low  2 ★   44
#        ID           Name  Age  Nationality                     Club  BP  \
# 0  184383      A. Pasche   26  Switzerland        FC Lausanne-Sport  CM
# 1  188044  Alan Carvalho   30     China PR  Beijing Sinobo Guoan FC  ST
#
#   Height  Weight   foot  Growth  ...     D/W   IR  PAC  SHO  PAS  DRI  DEF  \
# 0   5'9"  161lbs  Right       1  ...  Medium  1 ★   69   51   63   63   51
# 1   6'0"  159lbs  Right       0  ...     Low  2 ★   83   75   68   82   33
#
#    PHY  Hits  OVA
# 0   60     3   64
# 1   71    44   77
#
# [2 rows x 59 columns]

# %%
#X = '20M'
# def formating(X):
#     if 'K' in X:
#         X = X.replace('K','')
#         X = float(X)
#         X = X*1000
#         X = X.replace('€','')
#     elif 'M' in X:
#         X = X.replace('M','')
#         X = float(X)
#         X = X*1000000
#     elif 'lbs' in X:
#         X = X.replace('lbs','')
#         X = float(X)
#     elif '★' in X:
#         X = X.replace('★','')
#         X = float(X)
#     elif "'" in X:
#         X = X.replace("'",".")
#         X = float(X)
#     elif '"'in X:
#         X = X.replace('"','')
#         X = float(X)
#     return X

# data['Weight'] = list(map(formating,data['Weight']))
# # data['Height'] = list(map(formating,data['Height']))
# data['SM'] = list(map(formating,data['SM']))
# data['IR'] = list(map(formating,data['IR']))
# data['Wage'] = list(map(formating,data['Wage']))
# data['Value'] = list(map(formating,data['Value']))
# data['W/F'] = list(map(formating,data['W/F']))

# %% [markdown]
# #### Drop NaN values

# %%
data.dropna(inplace=True)
data.shape
# Out:
# (13358, 59)

# %% [markdown]
# #### Identify again numerical and categorical variables

# %%
numerical1 = data.select_dtypes(np.number)
categorical1 = data.select_dtypes(np.object)
numerical1
categorical1
# Out:
#            ID  Age  Growth  Crossing  Finishing  Heading Accuracy  \
# 0      184383   26       1        54         47                43
# 1      188044   30       0        66         79                76
# 2      184431   33       0        73         76                34
# 3      233796   22      13        44         42                58
# 4      234799   23       8        49         37                61
# ...       ...  ...     ...       ...        ...               ...
# 13695  239074   21      11        59         23                42
# 13696  241223   21       9        13          9                14
# 13697  210930   27       0        76         72                34
# 13698  162993   34       0        58         44                61
# 13699  254882   18      16        49         54                51
#
#        Short Passing  Volleys  Dribbling  Curve  ...  GK Kicking  \
# 0                 70     44.0         61   44.0  ...          14
# 1                 68     76.0         83   78.0  ...          14
# 2                 78     75.0         85   89.0  ...           6
# 3                 62     36.0         54   41.0  ...           6
# 4                 68     34.0         64   44.0  ...          15
# ...              ...      ...        ...    ...  ...         ...
# 13695             51     22.0         51   30.0  ...           7
# 13696             34      7.0          9   13.0  ...          57
# 13697             79     71.0         77   76.0  ...          16
# 13698             62     43.0         56   47.0  ...           9
# 13699             70     52.0         60   61.0  ...          11
#
#        GK Positioning  GK Reflexes  PAC  SHO  PAS  DRI  DEF  PHY  OVA
# 0                   9            6   69   51   63   63   51   60   64
# 1                   7           16   83   75   68   82   33   71   77
# 2                   3            3   80   77   78   86   27   56   80
# 3                   7           12   57   44   54   57   57   60   59
# 4                   5           15   66   44   60   64   60   66   65
# ...               ...          ...  ...  ...  ...  ...  ...  ...  ...
# 13695              10           13   76   28   46   55   53   57   60
# 13696              54           62   60   55   57   62   30   54   59
# 13697               9            6   65   69   78   77   39   60   76
# 13698               9            8   53   47   58   58   61   69   63
# 13699              11           12   64   54   62   62   50   47   60
#
# [13358 rows x 44 columns]
#                 Name  Nationality                        Club   BP Height  \
# 0          A. Pasche  Switzerland           FC Lausanne-Sport   CM   5'9"
# 1      Alan Carvalho     China PR     Beijing Sinobo Guoan FC   ST   6'0"
# 2        S. Giovinco        Italy                    Al Hilal  CAM   5'4"
# 3           J. Evans        Wales                Swansea City  CDM  5'10"
# 4         Y. Demoncy       France  US Orléans Loiret Football  CDM  5'11"
# ...              ...          ...                         ...  ...    ...
# 13695          S. Aw      Senegal              Gil Vicente FC   LB   5'8"
# 13696        S. Mogi        Japan                Cerezo Osaka   GK   6'5"
# 13697     Carles Gil        Spain      New England Revolution   RM   5'7"
# 13698       J. Perch      England              Mansfield Town  CDM  5'11"
# 13699  A. Oeynhausen      Germany             SC Paderborn 07  CAM  5'10"
#
#        Weight   foot  Value  Wage  W/F  SM     A/W     D/W   IR Hits
# 0      161lbs  Right  €525K   €4K  4 ★  2★    High  Medium  1 ★    3
# 1      159lbs  Right  €8.5M  €23K  3 ★  4★    High     Low  2 ★   44
# 2      134lbs  Right    €9M  €49K  4 ★  4★    High  Medium  2 ★   73
# 3      152lbs  Right  €275K   €4K  2 ★  2★  Medium  Medium  1 ★    7
# 4      150lbs  Right  €725K   €2K  2 ★  3★     Low  Medium  1 ★    4
# ...       ...    ...    ...   ...  ...  ..     ...     ...  ...  ...
# 13695  143lbs   Left  €325K   €1K  3 ★  2★    High  Medium  1 ★    4
# 13696  176lbs  Right  €190K  €700  2 ★  1★  Medium  Medium  1 ★    3
# 13697  146lbs   Left    €8M   €9K  4 ★  4★    High  Medium  2 ★   15
# 13698  176lbs  Right  €140K   €4K  3 ★  2★  Medium  Medium  1 ★    4
# 13699  150lbs  Right  €425K   €1K  3 ★  2★  Medium  Medium  1 ★    5
#
# [13358 rows x 15 columns]

# %% [markdown]
# ## 04 - Processing Data

# %%
corr_matrix = numerical1.corr()
# corr_matrix
# sns.heatmap(corr_matrix, annot=True)
# plt.show()

# %%
# We remove Reactions column because it is overcorrelated with our target OVA
data.drop(['Reactions'], axis=1, inplace=True)
data.shape
# Out:
# (13358, 58)

# %% [markdown]
# #### Separate x and y

# %%
data.shape

y= data['OVA']
x= data.drop(['OVA'], axis=1)

# Identify x numerical and x categorical
X_num = x.select_dtypes(np.number)
X_cat = x.select_dtypes(np.object)

X_num.shape
X_cat.shape
# Out:
# (13358, 58)
# (13358, 42)
# (13358, 15)

# %% [markdown]
# #### Normalize (numerical)

# %%
# Normalization
MinMaxtransformer = MinMaxScaler().fit(X_num)
x_normalized = MinMaxtransformer.transform(X_num)
print(x_normalized.shape)
x_normalized = pd.DataFrame(x_normalized,columns=X_num.columns)
x_normalized.head()
# Out:
# (13358, 42)
#          ID       Age    Growth  Crossing  Finishing  Heading Accuracy  \
# 0  0.711636  0.322581  0.038462  0.545455   0.478261          0.431818
# 1  0.725767  0.451613  0.000000  0.681818   0.826087          0.806818
# 2  0.711821  0.548387  0.000000  0.761364   0.793478          0.329545
# 3  0.902364  0.193548  0.500000  0.431818   0.423913          0.602273
# 4  0.906236  0.225806  0.307692  0.488636   0.369565          0.636364
#
#    Short Passing   Volleys  Dribbling     Curve  ...  GK Handling  GK Kicking  \
# 0       0.710843  0.465116   0.615385  0.444444  ...     0.111111    0.141304
# 1       0.686747  0.837209   0.857143  0.822222  ...     0.055556    0.141304
# 2       0.807229  0.825581   0.879121  0.944444  ...     0.011111    0.054348
# 3       0.614458  0.372093   0.538462  0.411111  ...     0.077778    0.054348
# 4       0.686747  0.348837   0.648352  0.444444  ...     0.077778    0.152174
#
#    GK Positioning  GK Reflexes       PAC       SHO       PAS       DRI  \
# 0        0.078652     0.045455  0.614286  0.447368  0.558824  0.522388
# 1        0.056180     0.159091  0.814286  0.763158  0.632353  0.805970
# 2        0.011236     0.011364  0.771429  0.789474  0.779412  0.865672
# 3        0.056180     0.113636  0.442857  0.355263  0.426471  0.432836
# 4        0.033708     0.147727  0.571429  0.355263  0.514706  0.537313
#
#         DEF       PHY
# 0  0.500000  0.515625
# 1  0.269231  0.687500
# 2  0.192308  0.453125
# 3  0.576923  0.515625
# 4  0.615385  0.609375
#
# [5 rows x 42 columns]

# %% [markdown]
# #### One Hot/Label Encoding (categorical).

# %%
# # Encoding Categorical Data.
# # Add the two categorical variables that might have the most influence in predicting the Total Claim Amount (TCA)
# X_cat = data[['Club','BP']]
# #One Hot Encoding 
# encoder = OneHotEncoder().fit(X_cat)
# X_cat_encoded = encoder.transform(X_cat).toarray()
# enc = [columname for sublist in encoder.categories_ for columname in sublist]
# onehot_encoded = pd.DataFrame(X_cat_encoded,columns=enc)
# onehot_encoded.head()
# onehot_encoded.shape

# %% [markdown]
# #### Concatenation and x,y split

# %%
# x_normalized.shape
# onehot_encoded.shape
# X = pd.concat([x_normalized, onehot_encoded],axis=1)
# X.head(2)

# %% [markdown]
# #### Train, test split

# %%
# Splitting into train set and test set.
X_train, X_test, y_train, y_test = train_test_split(x_normalized, y, test_size=0.25, random_state=100)
X_train.head()
# Out:
#              ID       Age    Growth  Crossing  Finishing  Heading Accuracy  \
# 12989  0.763910  0.322581  0.038462  0.636364   0.326087          0.715909
# 3228   0.818616  0.258065  0.153846  0.590909   0.597826          0.386364
# 10311  0.861009  0.322581  0.076923  0.056818   0.076087          0.068182
# 6694   0.936358  0.129032  0.384615  0.204545   0.293478          0.693182
# 10723  0.928059  0.129032  0.384615  0.420455   0.228261          0.704545
#
#        Short Passing   Volleys  Dribbling     Curve  ...  GK Handling  \
# 12989       0.783133  0.627907   0.736264  0.633333  ...     0.022222
# 3228        0.722892  0.686047   0.714286  0.600000  ...     0.133333
# 10311       0.228916  0.093023   0.076923  0.144444  ...     0.666667
# 6694        0.530120  0.325581   0.296703  0.266667  ...     0.100000
# 10723       0.554217  0.267442   0.637363  0.266667  ...     0.088889
#
#        GK Kicking  GK Positioning  GK Reflexes       PAC       SHO       PAS  \
# 12989    0.032609        0.022472     0.022727  0.357143  0.447368  0.676471
# 3228     0.108696        0.146067     0.068182  0.571429  0.552632  0.588235
# 10311    0.641304        0.685393     0.738636  0.585714  0.592105  0.514706
# 6694     0.119565        0.134831     0.136364  0.385714  0.236842  0.294118
# 10723    0.076087        0.123596     0.090909  0.585714  0.144737  0.294118
#
#             DRI       DEF       PHY
# 12989  0.656716  0.743590  0.687500
# 3228   0.626866  0.653846  0.656250
# 10311  0.582090  0.423077  0.562500
# 6694   0.134328  0.679487  0.734375
# 10723  0.507463  0.692308  0.734375
#
# [5 rows x 42 columns]

# %% [markdown]
# ## 05 - Modeling

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
#we train/fit our model
lm = linear_model.LinearRegression()
model = lm.fit(X_train,y_train)
# Out:
# (10018, 42)
# (3340, 42)
# (10018,)
# (3340,)

# %% [markdown]
# ## 06 - Model Validation

# %%
predictions = lm.predict(X_test)

# %%
# R2.
r2 = r2_score(y_test, predictions)
print(r2)
# MSE.
mse = mean_squared_error(y_test, predictions)
# RMSE.
rmse = math.sqrt(mse)
# Out:
# 0.8640699106927789

# %%
r2
# Out:
# 0.8640699106927789
